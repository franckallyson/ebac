# %% [markdown]
# # **Exercícios**

# %% [markdown]
# # Google Colab
#
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando print.
#
# Crie uma célua de texto e adicione uma imagem

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ![Capa de perfil para banner de linkedIn.png](data:image/png;base64,...)

# %% [markdown]
# # Números
#
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket
# médio abaixo:
#
# |Dia Valor Total |Vendas Qtd Total |Vendas| Ticket Medio|
# |---|---|---|---|
# |19/01|(A)| 3 |320.52|
# |20/01| 834.47| (B)| 119.21|
# |23/01| 15378.12| 5| (C)|

# %%
# (A) Valor total de vendas

qtd_total_vendas = 3
ticket_medio = 320.52

A = ticket_medio * qtd_total_vendas
print(f'(A) = {A}')


# (B) Quantidade total de vendas
valor_total_vendas = 834.47
ticket_medio = 119.21

B = valor_total_vendas / ticket_medio
print(f'(B) = {int(B)}')


# (C) Ticket Médio
valor_total_vendas = 15378.12
qtd_total_vendas = 5

C = valor_total_vendas / qtd_total_vendas
print(f'(C) = {C}')
# Out:
# (A) = 961.56
# (B) = 7
# (C) = 3075.6240000000003

# %% [markdown]
# # Strings
#
# Aplique três métodos distintos na string abaixo, você pode conferir alguns métodos neste link:
#
# cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
#
# Extraia da string abaixo o valor da taxa selic na variável selic e o valor do ano na variavel
# ano .
# Imprima os valores na tela.
#
# noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

metodo1 = cancao.upper()
metodo2 = cancao.split(',')
metodo3 = cancao.count('roda')

print(metodo1)
print(metodo2)
print(metodo3)
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# ['Roda mundo', ' roda gigante', ' roda moinho', ' roda pião.']
# 3

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

selic = float(noticia[12:16].replace(',', '.'))
ano = int(noticia[62])

print(selic)
print(ano)
# Out:
# 2.75
# 6

# %% [markdown]
# # Booleanos
#
# Bem simples, pois 'a' sendo False ao solicitar 'not a' teremos True.
#
# not a (True) and b (True)
#
# Na operação lógica and, os dois valores devem ser True para que a operação resulte em True, logo, x = True

# %%
a = False
b = True

x = not a and b
print(x)
# Out:
# True
